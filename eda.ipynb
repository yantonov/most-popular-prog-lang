# %%
import pandas as pd

# %%
df = pd.read_csv('./data/popularity.csv')

# %%
df.head()
# Out:
#              Date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi   Go  Groovy  \
# 0       July 2004  0.36  0.38   9.97  4.86   0.44   0.0    2.89  0.0    0.03
# 1     August 2004  0.37  0.38   9.65  5.20   0.48   0.0    2.78  0.0    0.07
# 2  September 2004  0.43  0.43   9.46  5.29   0.53   0.0    2.77  0.0    0.08
# 3    October 2004  0.42  0.39   9.16  5.43   0.55   0.0    2.84  0.0    0.09
# 4   November 2004  0.39  0.39   9.37  5.40   0.57   0.0    2.85  0.0    0.08
#
#    ...    PHP  Python     R  Ruby  Rust  Scala  Swift  TypeScript   VBA  \
# 0  ...  18.77    2.60  0.40  0.35  0.08   0.03    0.0         0.0  1.49
# 1  ...  18.88    2.75  0.42  0.41  0.10   0.03    0.0         0.0  1.52
# 2  ...  18.93    2.84  0.42  0.43  0.11   0.03    0.0         0.0  1.62
# 3  ...  18.92    2.99  0.43  0.47  0.12   0.04    0.0         0.0  1.65
# 4  ...  19.02    2.93  0.43  0.46  0.14   0.04    0.0         0.0  1.55
#
#    Visual Basic
# 0          8.84
# 1          8.96
# 2          8.82
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 29 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          194 non-null    object
#  1   Abap          194 non-null    float64
#  2   Ada           194 non-null    float64
#  3   C/C++         194 non-null    float64
#  4   C#            194 non-null    float64
#  5   Cobol         194 non-null    float64
#  6   Dart          194 non-null    float64
#  7   Delphi        194 non-null    float64
#  8   Go            194 non-null    float64
#  9   Groovy        194 non-null    float64
#  10  Haskell       194 non-null    float64
#  11  Julia         194 non-null    float64
#  12  Kotlin        194 non-null    float64
#  13  Java          194 non-null    float64
#  14  Javascript    194 non-null    float64
#  15  Lua           194 non-null    float64
#  16  Matlab        194 non-null    float64
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi   Go  Groovy  ...  \
# 0 2004-07-01  0.36  0.38   9.97  4.86   0.44   0.0    2.89  0.0    0.03  ...
# 1 2004-08-01  0.37  0.38   9.65  5.20   0.48   0.0    2.78  0.0    0.07  ...
# 2 2004-09-01  0.43  0.43   9.46  5.29   0.53   0.0    2.77  0.0    0.08  ...
# 3 2004-10-01  0.42  0.39   9.16  5.43   0.55   0.0    2.84  0.0    0.09  ...
# 4 2004-11-01  0.39  0.39   9.37  5.40   0.57   0.0    2.85  0.0    0.08  ...
#
#      PHP  Python     R  Ruby  Rust  Scala  Swift  TypeScript   VBA  \
# 0  18.77    2.60  0.40  0.35  0.08   0.03    0.0         0.0  1.49
# 1  18.88    2.75  0.42  0.41  0.10   0.03    0.0         0.0  1.52
# 2  18.93    2.84  0.42  0.43  0.11   0.03    0.0         0.0  1.62
# 3  18.92    2.99  0.43  0.47  0.12   0.04    0.0         0.0  1.65
# 4  19.02    2.93  0.43  0.46  0.14   0.04    0.0         0.0  1.55
#
#    Visual Basic
# 0          8.84
# 1          8.96
# 2          8.82
# 3          8.70
# ...

# %%
df.sum(axis=1)
# Out:
# 0      100.00
# 1      100.00
# 2      100.00
# 3      100.02
# 4      100.00
#         ...
# 189     99.98
# 190    100.01
# 191    100.02
# 192    100.00
# 193    100.01
# Length: 194, dtype: float64

# %%
languages = [lang for lang in df.columns if lang != 'Date']

# %%
languages
# Out:
# ['Abap',
#  'Ada',
#  'C/C++',
#  'C#',
#  'Cobol',
#  'Dart',
#  'Delphi',
#  'Go',
#  'Groovy',
#  'Haskell',
#  'Julia',
#  'Kotlin',
#  'Java',
#  'Javascript',
#  'Lua',
#  'Matlab',
#  'Objective-C',
#  'Perl',
#  'PHP',
#  'Python',
#  'R',
#  'Ruby',
#  'Rust',
#  'Scala',
#  'Swift',
#  'TypeScript',
#  'VBA',
#  'Visual Basic']

# %%
df.iloc[-1]
# Out:
# Date            2020-08-01 00:00:00
# Abap                           0.44
# Ada                            0.54
# C/C++                          5.88
# C#                             6.54
# Cobol                          0.42
# Dart                           0.57
# Delphi                         0.28
# Go                             1.39
# Groovy                         0.41
# Haskell                        0.32
# Julia                          0.43
# Kotlin                         1.57
# Java                           16.9
# Javascript                     8.17
# Lua                            0.52
# Matlab                         1.63
# Objective-C                     2.6
# Perl                           0.45
# PHP                            5.78
# Python                        31.59
# R                              4.18
# Ruby                           1.22
# Rust                           0.91
# Scala                          0.97
# Swift                          2.35
# ...

# %%
current_top_languages = list(df.iloc[-1][1:].sort_values()[-10:].index.values)

# %%
current_top_languages
# Out:
# ['TypeScript',
#  'Swift',
#  'Objective-C',
#  'R',
#  'PHP',
#  'C/C++',
#  'C#',
#  'Javascript',
#  'Java',
#  'Python']

# %% [markdown]
# Visualisation is done using streamlit.
#
# You can run it as follows
#
# ```bash
#     streamlit run app
# ```

# %% [markdown]
# Here is a screenshot:
# <img src="./images/top_languages.png"/>

# %% [markdown]
# Comparison of go and rust:
# <img src="./images/go-rust.png"/>

# %% [markdown]
# Comparison of python and r:
# <img src="./images/python-r.png"/>
